# %%
# import the packages
# read the data visadata
# cat num and numerical column

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r'C:\Users\PARBATII\Documents\Data_files\Visadataset.csv')

# %%
keys=visa_df.dtypes.keys()
values=visa_df.dtypes.values
for i,j in zip(keys,values):
    if j=='object':
        print(i)
    else:
        print(i)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# no_of_employees
# yr_of_estab
# region_of_employment
# prevailing_wage
# unit_of_wage
# full_time_position
# case_status

# %%
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(i)

# %%
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# **select_dtypes**

# %%
# object=categorial column=means english only

# visa_df.select_dtypes(include=None, exclude=None)
# select_dtype divide categorial column and numerical column separate
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat=visa_df.select_dtypes(include='object')
num=visa_df.select_dtypes(exclude='object')

# %%
cat
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
cat.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num.columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df['continent']   # S
visa_df[['continent']] # DF
visa_df.continent  #S
visa_df.iloc[:,1]  # S
visa_df.iloc[:,[1]] # DF
visa_df.loc[:,'continent']  # S
visa_df.loc[:,['continent']]  # DF
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df  # complete data  frame
visa_df['continent']   # single column(series)
visa_df['continent'].values   # raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df  # DF
visa_df['continent']   # S
visa_df['continent'].values   # raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %% [markdown]
# **continent**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %%
visa_df.dtypes.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 visa_df.dtypes.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
visa_df.dtypes.keys  # if we write this then it will give the indication if it needed ()
# Out:
# <bound method Series.keys of case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object>

# %% [markdown]
# **frequency table**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent']=='Asia'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
con=visa_df['continent']=='Asia'
asia_count=np.sum(con)
asia_count
# Out:
# np.int64(16861)

# %%
len(visa_df[con])
# Out:
# 16861

# %%
visa_df
con=visa_df['continent']=='Asia'
asia_count=np.sum(con)
asia_count
# Out:
# np.int64(16861)

# %%
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df[con])
# Out:
# 16861

# %%
selection ,extract ===  []
# Out:
#   Cell In[26], line 1
#     selection ,extract ===  []
#                          ^
# SyntaxError: invalid syntax

# %%
count=[]

con=visa_df['continent']==i
count.append(np.sum(con))
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(np.sum(con))

# %%
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
cont=visa_df['continent'].unique()
data=zip(cont,count)
pd.DataFrame(data)
# Out:
#                0      1
# 0           Asia  16861
# 1         Africa    551
# 2  North America   3292
# 3         Europe   3732
# 4  South America    852
# 5        Oceania    192

# %%
df1=pd.DataFrame(zip(cont,count),
                 columns=['continents','No.of applicants'])

# %%
df1.to_csv('continent.csv',index=False)

# %%
df1
# Out:
#       continents  No.of applicants
# 0           Asia             16861
# 1         Africa               551
# 2  North America              3292
# 3         Europe              3732
# 4  South America               852
# 5        Oceania               192

# %% [markdown]
# **value counts**

# %%
visa_df    # complete data frame
visa_df['continent']   # single column
visa_df['continent'].values  # raw data
visa_df['continent'].value_counts()   # counts
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['continent'].value_counts(normalize=True)   # percentile count
# Out:
# continent
# Asia             0.661735
# Europe           0.146468
# North America    0.129199
# South America    0.033438
# Africa           0.021625
# Oceania          0.007535
# Name: proportion, dtype: float64

# %%
visa_df['continent'].value_counts(normalize=True)*100   # percentage
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64

# %%
# data
# we selected one column
# we represent in a tabular format
# we need represent in a graphical

# %% [markdown]
# **Bar chart**

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192])

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
df1=pd.DataFrame(zip(keys,values),columns=['continent','No of applicants'])

# %%
df1.to_csv('continents.csv',index=False)

# %%
df1
# Out:
#        continent  No of applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192

# %%
# x=np.array(keys,values)
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.pie(values)
# Out:
# ([<matplotlib.patches.Wedge at 0x242ee1daf90>,
# ...
#  [Text(-0.5351742797933029, 0.9610351139514726, ''),
#   Text(-0.10373483734065869, -1.0950977506697324, ''),
#   Text(0.7670028608214846, -0.7884837420591869, ''),
#   Text(1.054611802949007, -0.31272023452383935, ''),
#   Text(1.092698639567901, -0.12652937637741896, ''),
#   Text(1.099691791437175, -0.02603773887449993, '')])

# %% [markdown]
# - frequency table we did from scartch also with method
#
#   - **value_count**:- count all the values that is keys and values
#
# - we selected a cat and num data types
#
#   - **select_dtypes**:- divide into categorial and numerical
#
# - we can select a single column or multiple columns
#
#   - **series or df(dataframe)**
#
# - if any one give two list to you ,you can able crate a dataframe
#
# - clear difference between
#
#       - dataframe:-combination of columns or combination of two or more list
#
#       - series:- single column
#
#       - values numpy format

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('continents')
plt.ylabel('No of applicants')
plt.title('continent_bar_chart')
plt.savefig('continent.jpg')
plt.show()

#            txt                 csv                    image
# where     diff or same         diff or same           diff or same
# what      data                  data                   image

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.bar(keys,values)
plt.figure(figsize=(10,4))
plt.xlabel('continents')
plt.ylabel('No of applicants')
plt.title('continent_bar_chart')
plt.savefig('continent.jpg')

# %%
plt.figure(figsize=(10,4))
colors=['red','yellow','orange','green', 'blue','black']

plt.bar(keys,values,color=colors)

plt.xlabel('continents')
plt.ylabel('No of applicants')

plt.title('continent_bar_chart')
plt.savefig('continent.jpg')

plt.show()    # plain show it always in last

# if we write in middle then it will not give the things output that written in below of show

# %%
import matplotlib
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__all__',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_afm',
#  '_api',
#  '_blocking_input',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_bivar',
#  '_cm_listed',
#  '_cm_multivar',
#  '_color_data',
#  '_constrained_layout',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_image',
#  '_init_tests',
#  '_label_from_arg',
#  '_layoutgrid',
#  '_log',
#  '_logged_cached',
# ...

# %%
from matplotlib import colors
dir(colors)
# Out:
# ['AsinhNorm',
#  'BASE_COLORS',
#  'BivarColormap',
#  'BivarColormapFromImage',
#  'BoundaryNorm',
#  'CSS4_COLORS',
#  'CenteredNorm',
#  'ColorConverter',
#  'ColorSequenceRegistry',
#  'Colormap',
#  'FuncNorm',
#  'Image',
#  'LightSource',
#  'LinearSegmentedColormap',
#  'ListedColormap',
#  'LogNorm',
#  'Mapping',
#  'MultivarColormap',
#  'NoNorm',
#  'Normalize',
#  'PngInfo',
#  'PowerNorm',
#  'Real',
#  'SegmentedBivarColormap',
#  'Sequence',
#  'Sized',
#  'SymLogNorm',
#  'TABLEAU_COLORS',
#  'TwoSlopeNorm',
#  'XKCD_COLORS',
#  '_BIVAR_REPR_PNG_SIZE',
#  '_ColorMapping',
#  '_REPR_PNG_SIZE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_check_color_like',
#  '_cm',
#  '_color_sequences',
#  '_colors_full_map',
#  '_create_empty_object_of_class',
#  '_create_lookup_table',
#  '_has_alpha_channel',
#  '_image',
#  '_is_nth_color',
#  '_make_norm_from_scale',
# ...

# %%
colors.CSS4_COLORS
# Out:
# {'aliceblue': '#F0F8FF',
#  'antiquewhite': '#FAEBD7',
#  'aqua': '#00FFFF',
#  'aquamarine': '#7FFFD4',
#  'azure': '#F0FFFF',
#  'beige': '#F5F5DC',
#  'bisque': '#FFE4C4',
#  'black': '#000000',
#  'blanchedalmond': '#FFEBCD',
#  'blue': '#0000FF',
#  'blueviolet': '#8A2BE2',
#  'brown': '#A52A2A',
#  'burlywood': '#DEB887',
#  'cadetblue': '#5F9EA0',
#  'chartreuse': '#7FFF00',
#  'chocolate': '#D2691E',
#  'coral': '#FF7F50',
#  'cornflowerblue': '#6495ED',
#  'cornsilk': '#FFF8DC',
#  'crimson': '#DC143C',
#  'cyan': '#00FFFF',
#  'darkblue': '#00008B',
#  'darkcyan': '#008B8B',
#  'darkgoldenrod': '#B8860B',
#  'darkgray': '#A9A9A9',
#  'darkgreen': '#006400',
#  'darkgrey': '#A9A9A9',
#  'darkkhaki': '#BDB76B',
#  'darkmagenta': '#8B008B',
#  'darkolivegreen': '#556B2F',
#  'darkorange': '#FF8C00',
#  'darkorchid': '#9932CC',
#  'darkred': '#8B0000',
#  'darksalmon': '#E9967A',
#  'darkseagreen': '#8FBC8F',
#  'darkslateblue': '#483D8B',
#  'darkslategray': '#2F4F4F',
# ...

# %%
# we need to draw a graph of categorial column
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(cat)   # as we know case id is not unique that's why it is not include
# Out:
# 9

# %%
visa_df['case_id'].nunique()
# we should avoid
# Out:
# 25480

# %%
len(cat[1:])
# Out:
# 8

# %%
keys=visa_df[i].value_counts().keys()
values=visa_df[i].value_counts().values
plt.figure(figsize=(10,4))
plt.xlabel('continents')
plt.ylabel('No of applicants')
plt.title('continent_bar_chart')
plt.savefig('continent.jpg')
plt.show() 
###########################################################
keys=visa_df['education'].value_counts().keys()
values=visa_df['education'].value_counts().values
plt.figure(figsize=(10,4))
plt.xlabel('education')
plt.ylabel('no.of student')
plt.title('education_bar_chart')
plt.savefig('education.jpg')
plt.show() 

keys=visa_df[i].value_counts().keys()
values=visa_df[i].value_counts().values
plt.figure(figsize=(10,4))
plt.xlabel(i)
plt.ylabel(i)
plt.title(f'{i}_bar_chart')
plt.savefig(f'{i}.jpg')
plt.show() 

# who is i?= categorial columns

# %%
# import 
# read
# cat,num

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.xlabel('Lablels')
    plt.ylabel('Count')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
# cat=visa_df.select_dtypes(include='object').columns
# plt.figure(figsize=(22,14))
# for i in cat[1:]:
#     keys=visa_df[i].value_counts().keys()
#     values=visa_df[i].value_counts().values
#     plt.bar(keys,values)
#     plt.xlabel('Lablels')
#     plt.ylabel('Count')
#     plt.title(f'{i}_bar_chart')
#     plt.savefig(f'{i}.jpg')
#     plt.show()

# %% [markdown]
# **subplot**

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.subplot(2,2,5)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1552, in subplot(*args, **kwargs)
#    1549 fig = gcf()
#    1551 # First, search for an existing subplot with a matching spec.
# -> 1552 key = SubplotSpec._from_subplot_args(fig, args)
#    1554 for ax in fig.axes:
#    1555     # If we found an Axes at the position, we can reuse it if the user passed no
#    1556     # kwargs or if the Axes class and kwargs are identical.
#    1557     if (ax.get_subplotspec() == key
#    1558         and (kwargs == {}
#    1559              or (ax._projection_init
#    1560                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
# ...

# %%
plt.subplot(2,2,3)
# Out:
# <Axes: >

# %%
# we need to plot 
# 1X8 not rec
# 8X1 (prev) not record
# 2X4 okay
# 4X2 not
# 3X3 okay

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)

for i in range(len(cat[1:])):
    plt.subplot(3,3,i+1)

# %%
for i,j in enumerate(cat[1:]):
    print(i,j)
# Out:
# 0 continent
# 1 education_of_employee
# 2 has_job_experience
# 3 requires_job_training
# 4 region_of_employment
# 5 unit_of_wage
# 6 full_time_position
# 7 case_status

# %%
for i,j in enumerate(cat[1:]):         #  i=0
    keys=visa_df[j].value_counts().keys()
    values=visa_df[j].value_counts().values
    ###########################################
    plt.figure(figsize=(10,4))
    plt.subplot(3,3,i+1)
    ############################################
    plt.bar(keys,values)
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
cat=visa_df.select_dtypes(include='object').columns
plt.figure(figsize=(22,14))
for i,j in enumerate(cat[1:]):         #  i=0
    keys=visa_df[j].value_counts().keys()
    values=visa_df[j].value_counts().values
    #########################
    plt.subplot(3,3,i+1)
    plt.bar(keys,values)
    #########################
    plt.xlabel('Lablels')
    plt.ylabel('Count')
    plt.title(f'{j}_bar_chart')
    plt.savefig(f'{j}.jpg')
plt.show()

# %%
cat=visa_df.select_dtypes(include='object').columns
plt.figure(figsize=(22,14))
for i in range(len(cat[1:])): #  i=0
    col=cat[1:][i]
    keys=visa_df[col].value_counts().keys()
    values=visa_df[col].value_counts().values
    #####################################################
    plt.subplot(3,3,i+1)
    plt.bar(keys,values)
    #########################################################
    plt.xlabel('Lablels')
    plt.ylabel('Count')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
plt.show()

# %%
count=visa_df['continent'].value_counts().head(6)
keys=count.index
values=count.values
plt.pie(values,labels=keys,autopct='%1.1f%%')
plt.show()

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.pie(values,labels=keys)
plt.title('continent_pie_chart')
plt.savefig('continent.jpg')
plt.show()

# %%
cat=visa_df.select_dtypes(include='object').columns
for i,j in enumerate(cat[1:]):
    keys=visa_df[j].value_counts().keys()
    values=visa_df[j].value_counts().values
    plt.figure(figsize=(8,4))
    plt.pie(values,labels=keys)
    plt.title(f'{i}_pie_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
cat=visa_df.select_dtypes(include='object').columns
plt.figure(figsize=(10,22))
for i,j in enumerate(cat[1:]):
    keys=visa_df[j].value_counts().index
    values=visa_df[j].value_counts().values
    plt.subplot(3,3,i+1)
    plt.pie(values,labels=keys,autopct="%1.1f%%")
    plt.title(f'{j}_pie_chart')
    plt.savefig(f'{j}.jpg')
plt.show()

# %%
dir(plt.pie)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__signature__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__',
#  '__wrapped__']
