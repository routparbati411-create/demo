# %% [markdown]
# **Step-1:Import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2: Create a Dataframe using list**

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,columns)
pd.DataFrame(Names)
# Out:
#          0
# 0   Ramesh
# 1   Suresh
# 2  Sathish

# %% [markdown]
# **step3:- Name the column**

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,clumns)
pd.DataFrame(Names,'NAMES')   #W
pd.DataFrame(Names,columns='NAMES')  # w
pd.DataFrame(Names,['NAMES']) # wrong
pd.DataFrame(Names,columns=['NAMES'])   # right

'Names','Age'
['Names','Age']

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,columns)
pd.DataFrame(Names,columns=['NAMES'])
# Out:
#      NAMES
# 0   Ramesh
# 1   Suresh
# 2  Sathish

# %% [markdown]
# **Step-4:Change the index**

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,columns)
pd.DataFrame(Names,index=['x','y','z'],columns=['NAMES'])
# Out:
#      NAMES
# x   Ramesh
# y   Suresh
# z  Sathish

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,columns)
pd.DataFrame(Names,
             index=['A','B','C']
             ,columns=['NAMES'])
# Out:
#      NAMES
# A   Ramesh
# B   Suresh
# C  Sathish

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,columns)
idx=['A','B','C']
cols=['NAMES']
pd.DataFrame(Names,cols,idx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 idx=['A','B','C']
#       4 cols=['NAMES']
# ----> 5 pd.DataFrame(Names,cols,idx)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:871, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     863         mgr = arrays_to_mgr(
#     864             arrays,
#     865             columns,
#    (...)    868             typ=manager,
#     869         )
#     870     else:
# --> 871         mgr = ndarray_to_mgr(
#     872             data,
#     873             index,
#     874             columns,
#     875             dtype=dtype,
#     876             copy=copy,
#     877             typ=manager,
#     878         )
#     879 else:
#     880     mgr = dict_to_mgr(
#     881         {},
#     882         index,
#    (...)    885         typ=manager,
# ...

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrame(data,index,clumns)
idx=['A','B','C']
cols=['NAMES']
pd.DataFrame(Names,idx,cols)
# Out:
#      NAMES
# A   Ramesh
# B   Suresh
# C  Sathish

# %% [markdown]
# **Step-5:two columns**

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
pd.DataFrame(zip(Names,Age))
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  22
# 2  Sathish  24

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
data=zip(Names,Age)
pd.DataFrame(data,columns=['NAMES','AGE'])
# Out:
#      NAMES  AGE
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
Names=['Ramesh','Suresh','Sathish']
age=[20,22,24]
data=zip(Names,Age)
cols=['NAMES','AGE']
pd.DataFrame(data,columns=cols)
# Out:
#      NAMES  AGE
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
data=zip(Names,Age)
cols=['NAMES','AGE']
idx=['A','B','C']
df=pd.DataFrame(data,idx,cols)
len(df)
# Out:
# 3

# %% [markdown]
# **Step-6:Add the data to empty dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# selection or update = []
# functions = ()

Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
data=zip(Names,Age)
cols=['NAMES','AGE']
df=pd.DataFrame(data,columns=cols)
df['NAMES']
# Out:
# 0     Ramesh
# 1     Suresh
# 2    Sathish
# Name: NAMES, dtype: object

# %%
df=pd.DataFrame()
df['Names']=['ramesh','Suresh','Sathish']
df['Age']=[20,22,24]

# %%
df
# Out:
#      Names  Age
# 0   ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df=pd.DataFrame()
df['Names']=[]

# %%
df=pd.DataFrame()
df['Names']=['ramesh','Suresh','Sathish']
df['Age']=[20,22]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 df=pd.DataFrame()
#       2 df['Names']=['ramesh','Suresh','Sathish']
# ----> 3 df['Age']=[20,22]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
# ...

# %% [markdown]
# - key error : no column
#
# - value error(dim error) : column length is mismatch(if two given instead of 3)

# %% [markdown]
# **Step-7: add the column to existed dataframe**

# %%
df['Cites']=['Hyd','Bglr','Delhi']

# %%
df
# Out:
#      Names  Age  Cites
# 0   ramesh   20    Hyd
# 1   Suresh   22   Bglr
# 2  Sathish   24  Delhi

# %% [markdown]
# **Step-8: Rename the column**

# %%
#  i want to rename Cites to city
# df.rename(mapper,index,columns,axis,inplace)
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
City=['hyd','bglr','delhi']
data=[Names,Age,City]
col=['Names','Age','City']
df=pd.DataFrame(data,columns=col)
d={'City':'city'}
df.rename(columns=d)
# Out:
#     Names     Age     city
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
df.rename(d)
# Out:
#     Names     Age     City
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
df.rename(d,axis=0)  # assume as axis=0 I need to change index No answer- No error
# Out:
#     Names     Age     City
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
df.rename(d,axis=1)
# Out:
#     Names     Age     city
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
df.rename(index=d)
# Out:
#     Names     Age     City
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
d={'Cites':'city'}    # column
df.rename(d)    # index
df.rename(d,axis=0)    # index
df.rename(d,axis=1) # col ===  work
df.rename(index=d)     # in
df.rename(columns=d)    # column=work
# Out:
#      Names  Age   city
# 0   ramesh   20    Hyd
# 1   Suresh   22   Bglr
# 2  Sathish   24  Delhi

# %%
df.rename(d,axis=1) 
df
# Out:
#     Names     Age     City
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
df.rename(d,axis=1,inplace=True)

# %%
df
# Out:
#     Names     Age     city
# 0  Ramesh  Suresh  Sathish
# 1      20      22       24
# 2     hyd    bglr    delhi

# %%
l=[20,10,30,40,50]
import random
random.shuffle(l)

# %%
l
# Out:
# [50, 20, 40, 10, 30]

# %%
df.columns=['Names','Age','City']

# %%
df.index=['A','B','C']

# %%
df
# Out:
#     Names     Age     City
# A  Ramesh  Suresh  Sathish
# B      20      22       24
# C     hyd    bglr    delhi

# %%
df.rename['City':'city']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.rename['City':'city']
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# **Step-9: Drop the column**

# %%
df=pd.DataFrame()
df['Names']=['ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['hyd','bglr','delhi']

# %%
df
# Out:
#      Names  Age   City
# 0   ramesh   20    hyd
# 1   Suresh   22   bglr
# 2  Sathish   24  delhi

# %%
# i want to drop city column
# df.drop(lables,axis,index,columns,level,inplace)
df.drop('City')    # error
df.drop('City',axis=0)    # error
df.drop(index=['City'])  # error
df.drop('City',axis=1)   # work
df.drop(columns=['City'])  # work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 # i want to drop city column
#       2 # df.drop(lables,axis,index,columns,level,inplace)
# ----> 3 df.drop('City')    # error
#       4 df.drop('City',axis=0)    # error
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
# ...

# %%
df.drop('City',axis=1)
# Out:
#      Names  Age
# 0   ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
Names=['Ramesh','Suresh','Sathish']
City=['Hyd','Blr','Pune']
Age=[20,22,24]
data=zip(Names,City,Age)
df=pd.DataFrame(data,
               index=['A','B','C'],
               columns=['Names','City','Age'])
###################################################
df.drop('City',axis=1,inplace=True)
df.drop('C',inplace=True)

# %%
df
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   22

# %% [markdown]
# - creating a dataframe
#
# - Name the column
#
# - Change the index
#
# - add the columns
#
# - add the data to empty dataframe
#
# - add the column to existing dataframe
#
# - rename the column
#
# - rename all the column and all the index at a time
#
# - drop the column
#
# - drop the index

# %%
# create a dataframe
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['Hyd','Blr','Pune']
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22   Blr
# 2  Sathish   24  Pune

# %%
df=pd.DataFrame()
df['Names']=['ramesh','Suresh','Sathish']
df['Age']=[20,22,24]

# %%
df['Cites']=['Hyd','Bglr','Delhi']

# %%
df.drop('Cites',axis=1)
# Out:
#      Names  Age
# 0   ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df.drop(2)
# Out:
#     Names  Age Cites
# 0  ramesh   20   Hyd
# 1  Suresh   22  Bglr

# %%
df.drop('Cites',axis=1,inplace=True)

# %%
df
# Out:
#      Names  Age
# 0   ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df.drop('Cites',axis=1,inplace=True)
df.drop(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.drop('Cites',axis=1,inplace=True)
#       2 df.drop(2)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
City=['hyd','bglr','delhi']
data=[Names,Age,City]
col=['Names','Age','City']
df=pd.DataFrame(data,columns=col)
df.drop('City',axis=1,inplace=True)
df
# Out:
#     Names     Age
# 0  Ramesh  Suresh
# 1      20      22
# 2     hyd    bglr

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
City=['hyd','bglr','delhi']
data=zip(Names,Age,City)
col=['Names','Age','City']
df=pd.DataFrame(data,columns=col)
df.drop('City',axis=1,inplace=True)
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df.drop(2,inplace=True)

# %%
df
# Out:
#     Names     Age
# 0  Ramesh  Suresh
# 1      20      22

# %%
- inplace = True it will drop permanently or it will overwrite

# %% [markdown]
# **Step-10: replace**

# %%
# create a dataframe
import pandas as pd
Names=['sita','gita','mita']
Age=[21,23,25]
data=zip(Names,Age)
col=['NAMES','AGE']
df=pd.DataFrame(data,columns=col)
df.replace('sita','rita')
# Out:
#   NAMES  AGE
# 0  rita   21
# 1  gita   23
# 2  mita   25

# %%
# df.replace(
#     to_replace=None,
#     value=<no_default>,
#     *,
#     inplace: 'bool_t' = False,
#     limit: 'int | None' = None,
#     regex: 'bool_t' = False,
#     method: "Literal['pad', 'ffill', 'bfill'] | lib.NoDefault" = <no_default>,
# ) -> 'Self | None'

# df.replace(to_replace,value)

df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['Hyd','Bglr','Pune']
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22  Bglr
# 2  Sathish   24  Pune

# %%
df.replace('Hyd','Chennai')   # inplace not happend so it will not overwrite
# Out:
#      Names  Age     City
# 0   Ramesh   20  Chennai
# 1   Suresh   22     Bglr
# 2  Sathish   24     Pune

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22  Bglr
# 2  Sathish   24  Pune

# %%
df['Names']='Mahesh'
df['Age']=24
df['City']='Hyd'

# %%
df
# Out:
#     Names  Age City
# 0  Mahesh   24  Hyd
# 1  Mahesh   24  Hyd
# 2  Mahesh   24  Hyd

# %%
df.replace('Ramesh','Mahesh')   # inplace not happened so it will not overwrite
# Out:
#      Names  Age   City
# 0   Mahesh   20    Hyd
# 1   Suresh   21   Bglr
# 2  Sathish   22  Delhi

# %%
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish','Mahesh']
df['Age']=[20,22,24,24]
df['City']=['Hyd','Bglr','Pune','Hyd']
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22  Bglr
# 2  Sathish   24  Pune
# 3   Mahesh   24   Hyd

# %%
df.replace('Hyd','Chennai')
# Out:
#      Names  Age     City
# 0   Ramesh   20  Chennai
# 1   Suresh   22     Bglr
# 2  Sathish   24     Pune
# 3   Mahesh   24  Chennai

# %%
df['Marks']=[25,24,23,22]

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22  Bglr     24
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
df.replace(24,20)
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22  Bglr     20
# 2  Sathish   20  Pune     23
# 3   Mahesh   20   Hyd     22

# %%
# all the data in same will change
# all the column data will change

df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22  Bglr     24
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
- in thiss also the age is change so his is disadavantage
- so we have to overcome this like this

# %%
df['Marks'].replace(24,20,inplace=True)
# Out:
# C:\Users\PARBATII\AppData\Local\Temp\ipykernel_8164\602866676.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].replace(24,20,inplace=True)

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22  Bglr     20
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %% [markdown]
# **Step-11:np.where**

# %%
# i want to change city name to Chennai
# for the canditate who has age 24

# %%
import numpy as np

# %%
np.where(condition,True,False)
age==24
True Chennai
False No change

# %%
# i need to apply condition on age column
# we need to select a column

con=df['Age']==24
true='Chennai'
false=df['City']

# %%
np.where(con,true,false)
# Out:
# array(['Hyd', 'Bglr', 'Chennai', 'Chennai'], dtype=object)

# %%
df['City']=np.where(con,true,false)

# %%
df
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22

# %%
# big4
# Delloite , EY,PWC,KPMG
# MAANG: MICROSOFT,AMAZON,APPLE,NV,GOOGLE
# #                  developer
#                    skills DATA stuctures
# create products
# SQL VS PANDAS   - Mr.Shiv Rama


mr sivrama krishna---- pandas class

# %% [markdown]
# **Step-12:Append a row**

# %%
df
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22

# %% [markdown]
# **loc-iloc**

# %%
df.loc[rows,columns]
   rows are index numbers similar to list slice
   l[start:stop:end]
    column are names any column name we can provide
df.iloc[rows,columns]
  rows and columns are index numbers similar to list slice
  l[start:stop:step]

# %%
df.loc[[1,2,3]]
# Out:
#      Names  Age     City  Marks
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22

# %%
df.loc[1:2]
# Out:
#      Names  Age     City  Marks
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23

# %%
rows=[1,2,3]
cols=['Age','City']
df.loc[rows,cols]
# Out:
#    Age     City
# 1   22     Bglr
# 2   24  Chennai
# 3   24  Chennai

# %%
rows=[1,2,3]
cols=[1,2]   # index['age']=1,index['city']=2
df.iloc[rows,cols]
# Out:
#    Age     City
# 1   22     Bglr
# 2   24  Chennai
# 3   24  Chennai

# %%
cols=['Age','City']
df.loc[1:3,cols]
# Out:
#    Age     City
# 1   22     Bglr
# 2   24  Chennai
# 3   24  Chennai

# %%
df.loc[len(df)]=['Anish',26,'Mumbai',25]

# %%
df
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22
# 4    Anish   26   Mumbai     25

# %%
cols=[1,2]
df.iloc[1:3,cols]
# Out:
#    Age     City
# 1   22     Bglr
# 2   24  Chennai

# %%
df.iloc[1:3,1:2]
# Out:
#    Age
# 1   21
# 2   22

# %%
df.loc[1]
# Out:
# Names    Suresh
# Age          21
# City       Bglr
# Marks        20
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Names    Sathish
# Age           22
# City       Delhi
# Marks         23
# Name: 2, dtype: object

# %%
df.loc[3]
# Out:
# Names     Mahesh
# Age           24
# City     Chennai
# Marks         22
# Name: 3, dtype: object

# %%
df.loc[4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 4 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.loc[4]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df.loc[4]=['Anish',25,'Mumbai',26]

# %%
df
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   21     Bglr     20
# 2  Sathish   22    Delhi     23
# 3   Mahesh   24  Chennai     22
# 4    Anish   25   Mumbai     26

# %% [markdown]
# **Step-13:How to save the dataframe**

# %%
# directory : where is the file is available
# name:  what is the name of the file
# extension : what is the type of file(extension of the the name file)

# ##########################################
#     SAME PYTHON (LOCATION)PATH
# name: what is the name of the file
# extension :what is the type of file 


# # dataframe variable= df
# name : student
# extension : .csv and .xlsx for pandas

df.to_csv('student.csv')

# %%
pd.read_csv('student.csv')
# Out:
#    Unnamed: 0    Names  Age     City  Marks
# 0           0   Ramesh   20      Hyd     25
# 1           1   Suresh   22     Bglr     20
# 2           2  Sathish   24  Chennai     23
# 3           3   Mahesh   24  Chennai     22
# 4           4    Anish   26   Mumbai     25

# %%
df.to_excel('student.xlsx')

# %%
pd.read_excel('student.xlsx')
# Out:
#    Unnamed: 0    Names  Age     City  Marks
# 0           0   Ramesh   20      Hyd     25
# 1           1   Suresh   22     Bglr     20
# 2           2  Sathish   24  Chennai     23
# 3           3   Mahesh   24  Chennai     22
# 4           4    Anish   26   Mumbai     25

# %% [markdown]
# **Step-14: ignore index**

# %%
df.to_csv('student.csv',index=False)

# %%
pd.read_csv('student.csv')
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22
# 4    Anish   26   Mumbai     25

# %%
df.to_excel('student.xlsx',index=False)

# %%
pd.read_excel('student.xlsx')
# Out:
#      Names  Age     City  Marks
# 0   Ramesh   20      Hyd     25
# 1   Suresh   22     Bglr     20
# 2  Sathish   24  Chennai     23
# 3   Mahesh   24  Chennai     22
# 4    Anish   26   Mumbai     25

# %%
# take a new notebook
# in your datafiles'
#   visadataset
#   bankdataset pls load that

# %%
df=pd.read_csv(r'C:\Users\PARBATII\Documents\Data_files\Visadataset.csv')

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
Name=['Aman','Priya','Rahul','Sneha','Kiran','John','Meena','Arjun','Sara','David']
Age=[21,22,20,23,None,21,22,20,23,24]
Gender=['M','F','M','F','M','M','F','M','F','M']
Course=['DS','AI','ML','DS','AI','ML','DS','AI','ML','DS','AI','ML','DS']
Marks=[85,90,78,92,88,None,95,80,76,89]
City=['Hyderbad','Delhi','Mumbai','Chennai','Delhi','Mumbai','Hyderbad','Pune','Chennai','Delhi']
Fees=[50000,55000,52000,50000,55000,52000,50000,55000,52000,50000]
data=zip(Name,Age,Gender,Course,Marks,City,Fees)
cols=['Name','Age','Gender','Course','Marks','City','Fees']
df=pd.DataFrame(data,columns=cols)
df.fillna(' ')
# Out:
#     Name   Age Gender Course Marks      City   Fees
# 0   Aman  21.0      M     DS  85.0  Hyderbad  50000
# 1  Priya  22.0      F     AI  90.0     Delhi  55000
# 2  Rahul  20.0      M     ML  78.0    Mumbai  52000
# 3  Sneha  23.0      F     DS  92.0   Chennai  50000
# 4  Kiran            M     AI  88.0     Delhi  55000
# 5   John  21.0      M     ML          Mumbai  52000
# 6  Meena  22.0      F     DS  95.0  Hyderbad  50000
# 7  Arjun  20.0      M     AI  80.0      Pune  55000
# 8   Sara  23.0      F     ML  76.0   Chennai  52000
# 9  David  24.0      M     DS  89.0     Delhi  50000

# %%
df.fillna(' ')
# Out:
#     Name   Age Gender Course Marks      City   Fees
# 0   Aman  21.0      M     DS  85.0  Hyderbad  50000
# 1  Priya  22.0      F     AI  90.0     Delhi  55000
# 2  Rahul  20.0      M     ML  78.0    Mumbai  52000
# 3  Sneha  23.0      F     DS  92.0   Chennai  50000
# 4  Kiran            M     AI  88.0     Delhi  55000
# 5   John  21.0      M     ML          Mumbai  52000
# 6  Meena  22.0      F     DS  95.0  Hyderbad  50000
# 7  Arjun  20.0      M     AI  80.0      Pune  55000
# 8   Sara  23.0      F     ML  76.0   Chennai  52000
# 9  David  24.0      M     DS  89.0     Delhi  50000
