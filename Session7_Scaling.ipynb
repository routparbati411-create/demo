# %% [markdown]
# **Feature Scaling**
#
# - Feature scaling is a method ,to modify the value either increase or decrease
#
# - In ML we have different columns
#
#    - age range between 0 to 100
#
#    - height range between 0 to 200cm
#
#    - income range between 10k to 1 crore
#
# - different columns having different range of values also different units
#
# - ML models might be think more leads to more impact
#
# - Distanc based algorithms are need to be scale
#
# - Deep learning main aim is lower the error : Convergence
#
# -Standard Scalar
#
#   - Z scale
#
#   - 99.7 of data lies between -3 to 3
#
#   - Mainly used in ML
#
# - MinMaxScalar
#
#   - Normalization
#
#   - all the data lies between 0 to 1
#
#   - Mainly used in images scaling
#
#   - Generally Color image values 0 to 255 R G B channel
#
#   - Gray images ranges 0 to 1,0 means Black 1 means White

# %%
- Model always deals with numbers

- a column has more values than model feels that column has high impact

- A king lives in kingdom,a king always stay hungry and eat a food

- here a is repeated four itb takes it as imoportant but reaklly king is important

# %%
STANDARDIZATION -3 to 3                     NORMALIZATION (0,1)
NORMALIZATION(0,1): x-xmin/xmax-xmin
0 to 255 - pixel image or color image
0 - Black
255 - White
image has 3 color layers or channels= RGB
5X5=25 pixels
25+25+25=75   or 5X5X3=75
any colour is 3D data- 5X5X3 (height,width,depth)  
depth 3 (channel)- Red Green Blur
but if 5X5 then it gives only black and white

# %% [markdown]
# **Standardization**

# %% [markdown]
# **Z scale**

# %% [markdown]
# <img src="https://substackcdn.com/image/fetch/$s_!V5CZ!,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Ff4b23f94-2aa6-48ec-8753-7076415e2705_778x422.png" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 778px; height: 101px; margin: 22.5px 0px; width: 187px;" alt="Standardization vs Normalization: The Feature Scaler Role - NBD Lite #15" jsname="kn3ccd">

# %%
import pandas as pd
file_path=r'C:\Users\PARBATII\Documents\Data_files\Visadataset.csv'
visa_df=pd.read_csv(file_path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
# step-1: take the prevailing wage data
# step-2: calculate mean
# step-3: calculate sd
# step-4: Nr=step1-step2
# step-5:z_data=Step4/Step3
# step-6: draw the subplots s1 and s5
#         both histogram and boxplot

# %%
wage_data=visa_df['prevailing_wage']

# %%
wage_mean=np.mean(wage_data)
wage_mean
# Out:
# np.float64(74455.81459209183)

# %%
std_wage=np.std(wage_data)
std_wage
# Out:
# 52814.90589711402

# %%
Numerator=wage_data-std_wage
Numerator
# Out:
# 0        -52222.702997
# 1         30610.744103
# 2         70181.954103
# 3         30619.124103
# 4         97092.484103
#              ...
# 25475     24277.664103
# 25476    226359.884103
# 25477     93483.944103
# 25478     33339.864103
# 25479     18062.004103
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
z_data=Numerator/std_wage
z_data
# Out:
# 0       -0.988787
# 1        0.579585
# 2        1.328829
# 3        0.579744
# 4        1.838354
#            ...
# 25475    0.459674
# 25476    4.285909
# 25477    1.770030
# 25478    0.631259
# 25479    0.341987
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(z_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([-0.99995954, -0.39556931,  0.20882092,  0.81321116,  1.41760139,
#          2.02199163,  2.62638186,  3.23077209,  3.83516233,  4.43955256,
#          5.0439428 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.subplot(2,2,1).boxplot(wage_data)
plt.subplot(2,2,2).boxplot(z_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24fafc85590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24fafc85810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24fafc85450>],
#  'medians': [<matplotlib.lines.Line2D at 0x24fafc85a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24fafc85bd0>],
#  'means': []}

# %%
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(z_data)
plt.subplot(2,2,3).boxplot(wage_data)
plt.subplot(2,2,4).boxplot(z_data)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=np.mean(wage_data)
wage_sd=np.std(wage_data)
Nr=wage_data-wage_mean
z_wage=Nr/wage_sd

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(z_wage)
plt.subplot(2,2,3).boxplot(wage_data)
plt.subplot(2,2,4).boxplot(z_wage)
plt.show()

# %% [markdown]
# - sklearn
#
#    - preprocessing
#
#        - StandardScalar
#
#            - fit_transformm

# %%
# again read the data
# again read wage  
# for output sc_wage
# plot the subplot
wage_data=visa_df[['prevailing_wage']]
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss.fit_transform(wage_data)
# Out:
# array([[-1.39853722],
#        [ 0.1698353 ],
#        [ 0.91907852],
#        ...,
#        [ 1.36027953],
#        [ 0.22150859],
#        [-0.06776315]], shape=(25480, 1))

# %%
sc_wage=ss.fit_transform(visa_df[['prevailing_wage']])

# %%
plt.subplot(2,2,1).hist(sc_wage)
plt.subplot(2,2,2).boxplot(sc_wage)
plt.show()

# %% [markdown]
# **Normalization**
#
# - using scratch
#
#      - read the wage data
#
#      - cal min and max
#
# -  using package
#
#      - sklearn
#
#      - preprocessing
#
#      - MinMaxScalar

# %% [markdown]
# <img src="https://media.licdn.com/dms/image/v2/C4D12AQHtBtkiD06l2Q/article-cover_image-shrink_600_2000/article-cover_image-shrink_600_2000/0/1616512439644?e=2147483647&amp;v=beta&amp;t=mEH2obtUahAQ0oLcTs1zN24APYrJznJQcVZ_h1gaBhg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1024px; height: 82px; margin: 32px 0px; width: 182px;" alt="Why do you need to normalize your data in Machine Learning?" jsname="kn3ccd">m

# %%
wage_data=visa_df['prevailing_wage']
Min=np.min(wage_data)
Max=np.max(wage_data)
nr=wage_data-Min
dr=Max-Min
norm=nr/dr
norm
# Out:
# 0        0.001849
# 1        0.261345
# 2        0.385312
# 3        0.261371
# 4        0.469616
#            ...
# 25475    0.241505
# 25476    0.874579
# 25477    0.458311
# 25478    0.269895
# 25479    0.222033
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
plt.subplot(2,2,1).hist(norm)
plt.subplot(2,2,2).boxplot(norm)
plt.show()

# %%
wage_data=visa_df[['prevailing_wage']]
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
mms_wage_data=mms.fit_transform(wage_data)

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(mms_wage_data)
plt.subplot(1,2,2).boxplot(mms_wage_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24fb3b73b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24fb3b73d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24fb3b739d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24fb3b94050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24fb3b94190>],
#  'means': []}

# %%
wage_data=visa_df['prevailing_wage']

# %%
- why you choose datascience
            python
           --------
-what is python ?
High level interpreted programming languange
it is the rich set of a library
it maintains automatic memory management system
it is the open source Freeware   ex:- jython,micro python,anaconda
opensource- anyone can accesss
freeware- we can modify the source code
Highlevel- convert the source code to binary or machine level language
interpreted - line by line find the errror

- what is cmd?

NON GUI- 

what is os?
Guido VAN ROSSUM -> 1991 Monty python flying circus
0.9.0
ABC
python not support backward compatibility
ex- PYTHON 2.7 (SIX,2 TO 3)

bug- problem in logic or logical error
error - syntax error
features of python:-
EASY AND SIMPLE
interpreted language
high level
o open source
dynamic
it supports POP and OOP
Independent 
Robust
Portable language and Scalable

Compilation
-> source code (.py) -> .pyc(byte code)
->pvm
  .pyc -> binary


- keywords
there are 7 types 
fundamental keyword  - True False
logical and arithmetic keyword
membership and identity keyword
control flow keyword
   ->conditional keyword
   ->Iterative keyword
   ->Transfer keyword
function based keyword
ExceptionHandling keyword and file handling 
Class level  keywords module level keywords
Other keywords

# %%
pd.merge
pd.join
pd.concatenate

# %%
a=15
print(a)
# Out:
# 15

# %%
print(string:="hello babyy")
# Out:
# hello babyy

# %%
def add(a:int,b:int) ->int:
    return a+b
add(5,9)
# Out:
# 14
